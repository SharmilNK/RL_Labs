# %% [markdown]
# <a href="https://colab.research.google.com/github/SharmilNK/RL_Labs/blob/main/RL_CH1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Train and evaluate a deep RL agent ( PPO ) in a stochastic, procedurally generated environment ( MiniGrid), identify a failure mode (poor generalization) and propose a mitigation strategy.

# %%
# !pip install -q minigrid stable-baselines3 gymnasium
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gymnasium as gym
import numpy as np
import minigrid
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# Create the enviroment
#
# Procedurally Generated Environment :  MiniGrid-MultiRoom-N2-S4-v0

# %%
env_id = "MiniGrid-MultiRoom-N2-S4-v0"

def make_env(seed):
    env = gym.make(env_id)
    env = FlatObsWrapper(env)
    env.reset(seed=seed)
    return env

# %% [markdown]
# Create the PPO agent

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# Training seeds: 0–99 (100 different procedural layouts)
#
# Test seeds: 100–119 (held-out seeds for evaluation)

# %% [markdown]
# Create Training environment

# %%
from stable_baselines3.common.vec_env import DummyVecEnv

# Increased train seeds for better diversity and generalization
train_seeds = list(range(0, 100))  # 100 different procedural layouts

class RandomSeedWrapper(gym.Wrapper):
    """On each reset, use a random train seed so each episode sees a different procedural layout."""
    def __init__(self, env, seeds):
        super().__init__(env)
        self.seeds = seeds
    def reset(self, **kwargs):
        seed = int(np.random.choice(self.seeds))
        kwargs.pop("seed", None)  # avoid passing seed twice
        return self.env.reset(seed=seed, **kwargs)

def make_train_env():
    env = gym.make(env_id)
    env = FlatObsWrapper(env)
    env = RandomSeedWrapper(env, train_seeds)
    env.reset(seed=int(np.random.choice(train_seeds)))
    return env

env = DummyVecEnv([make_train_env])

# %% [markdown]
# Train PPO agent

# %%
# Improved hyperparameters for better learning
model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    ent_coef=0.01,  # Entropy bonus for exploration
    learning_rate=3e-4,
    n_steps=2048,  # Steps per environment per update
    batch_size=64,
    n_epochs=10,  # Number of optimization epochs per update
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    tensorboard_log="./ppo_minigrid_tensorboard/"
)

# Train for more timesteps to improve learning and generalization
model.learn(total_timesteps=500000)
# Out:
# Using cpu device
# Logging to ./ppo_minigrid_tensorboard/PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 481  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017017473 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -2.08       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0379     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.018       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 219          |
# |    iterations           | 3            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0140270535 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | -0.46        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00262     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0169      |
# |    value_loss           | 0.00237      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 4           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012428945 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | -2.47       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0169     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 0.000329    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 204       |
# |    iterations           | 5         |
# |    time_elapsed         | 50        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0116246 |
# |    clip_fraction        | 0.119     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.88     |
# |    explained_variance   | 0.31      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.000384 |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -0.0185   |
# |    value_loss           | 0.00086   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 6           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016181165 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0398     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 0.00206     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 7           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008818272 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0239     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 0.00269     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 225          |
# |    iterations           | 8            |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0112008415 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.32         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0549      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0213      |
# |    value_loss           | 0.00136      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 9           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015228213 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.224       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0598     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 0.00178     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 10          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013971118 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0461     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 0.00105     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 11          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013375848 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0321     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 0.00771     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 12          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014735622 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0738     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 0.00924     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 13          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013151827 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00798    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 0.0149      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 14          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015756685 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0546     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0299     |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 15          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014782285 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0471     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.026      |
# |    value_loss           | 0.0159      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 16          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016376447 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0816     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0326     |
# |    value_loss           | 0.0142      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 17          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.017038517 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0319     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 0.0135      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 223         |
# |    iterations           | 18          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.017394632 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0513     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0234     |
# |    value_loss           | 0.0128      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 19          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.022554379 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0444     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 0.00945     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 20          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015457237 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 0.00573     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 21          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014543657 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.452       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00235    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 0.00364     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 22          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.014994145 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00236    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 0.00221     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 23          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012534466 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.379      |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.00208     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 24          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015984222 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.381      |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00757    |
# |    value_loss           | 0.00396     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 25           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0113881705 |
# |    clip_fraction        | 0.0754       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.3         |
# |    explained_variance   | 0.312        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00269     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00531     |
# |    value_loss           | 0.00281      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 26          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011540845 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.285      |
# |    explained_variance   | 0.38        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00943    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00726    |
# |    value_loss           | 0.00237     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 27          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.018109344 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.229      |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00754    |
# |    value_loss           | 0.0018      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 184         |
# |    iterations           | 28          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.016608756 |
# |    clip_fraction        | 0.0819      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.247      |
# |    explained_variance   | 0.266       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00309    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.000695    |
# |    value_loss           | 0.00211     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 29          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009985806 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.216      |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00463    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00732    |
# |    value_loss           | 0.00235     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 30          |
# |    time_elapsed         | 348         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009989594 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.21       |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00183    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00402    |
# |    value_loss           | 0.00408     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 173        |
# |    iterations           | 31         |
# |    time_elapsed         | 366        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.01587812 |
# |    clip_fraction        | 0.0426     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.145     |
# |    explained_variance   | 0.263      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0247     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00536   |
# |    value_loss           | 0.00148    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 169          |
# |    iterations           | 32           |
# |    time_elapsed         | 385          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0063921423 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.163       |
# |    explained_variance   | 0.455        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0114      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00908     |
# |    value_loss           | 0.00145      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 33          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.018846761 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.143      |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0122      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00679    |
# |    value_loss           | 0.00134     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 34          |
# |    time_elapsed         | 424         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.017310908 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.155      |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0165     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00485    |
# |    value_loss           | 0.00184     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 35          |
# |    time_elapsed         | 443         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.029871296 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.127      |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0314     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.00192     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 36          |
# |    time_elapsed         | 462         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.015547612 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.118      |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00604     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00804    |
# |    value_loss           | 0.00398     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 37          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.033750422 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.122      |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0042     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00105     |
# |    value_loss           | 0.0017      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 38          |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011383506 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.14       |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00334    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00952    |
# |    value_loss           | 0.00331     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 39          |
# |    time_elapsed         | 518         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.029232858 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.129      |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0232     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 0.00218     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 40          |
# |    time_elapsed         | 537         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013132939 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.164      |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0332      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 0.00228     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 150        |
# |    iterations           | 41         |
# |    time_elapsed         | 556        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.00864612 |
# |    clip_fraction        | 0.0634     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.125     |
# |    explained_variance   | 0.422      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0104    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00553   |
# |    value_loss           | 0.00131    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 42          |
# |    time_elapsed         | 575         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.019035753 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.125      |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00959    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00666    |
# |    value_loss           | 0.00255     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 43          |
# |    time_elapsed         | 594         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.012758926 |
# |    clip_fraction        | 0.0165      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0512     |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00271    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 0.000998    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 146          |
# |    iterations           | 44           |
# |    time_elapsed         | 614          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0017286274 |
# |    clip_fraction        | 0.00928      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0395      |
# |    explained_variance   | 0.464        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00074      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000379    |
# |    value_loss           | 0.000937     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 145          |
# |    iterations           | 45           |
# |    time_elapsed         | 635          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0022498968 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.051       |
# |    explained_variance   | 0.474        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00617     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 0.000909     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 46          |
# |    time_elapsed         | 655         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011588728 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0591     |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00754    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.003      |
# |    value_loss           | 0.000905    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 142        |
# |    iterations           | 47         |
# |    time_elapsed         | 674        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.00361073 |
# |    clip_fraction        | 0.0181     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0623    |
# |    explained_variance   | 0.475      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00635   |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.000584  |
# |    value_loss           | 0.000783   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 48          |
# |    time_elapsed         | 686         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005523756 |
# |    clip_fraction        | 0.021       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0804     |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00367     |
# |    value_loss           | 0.00101     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 142          |
# |    iterations           | 49           |
# |    time_elapsed         | 702          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0067147706 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.114       |
# |    explained_variance   | 0.346        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.017       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0056      |
# |    value_loss           | 0.00151      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 50          |
# |    time_elapsed         | 717         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.012776067 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000963   |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.000239   |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 142        |
# |    iterations           | 51         |
# |    time_elapsed         | 733        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.00966805 |
# |    clip_fraction        | 0.0518     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.108     |
# |    explained_variance   | 0.407      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0121    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.000317  |
# |    value_loss           | 0.00143    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 142        |
# |    iterations           | 52         |
# |    time_elapsed         | 748        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.02803432 |
# |    clip_fraction        | 0.0693     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.145     |
# |    explained_variance   | 0.402      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00908   |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00694   |
# |    value_loss           | 0.00118    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 53          |
# |    time_elapsed         | 765         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.016633552 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.265      |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00939    |
# |    value_loss           | 0.00311     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 54          |
# |    time_elapsed         | 782         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.037846453 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.202      |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0155     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 0.0031      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 55          |
# |    time_elapsed         | 797         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.017110106 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.161      |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.00291     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 56          |
# |    time_elapsed         | 812         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.025849149 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0912     |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0023     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00961    |
# |    value_loss           | 0.00122     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 57          |
# |    time_elapsed         | 826         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.015105165 |
# |    clip_fraction        | 0.0511      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.131      |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0243      |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 141        |
# |    iterations           | 58         |
# |    time_elapsed         | 841        |
# |    total_timesteps      | 118784     |
# | train/                  |            |
# |    approx_kl            | 0.03155765 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.3       |
# |    explained_variance   | 0.289      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.026     |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 0.00575    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 59          |
# |    time_elapsed         | 855         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.028290419 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.275      |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00411     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00936    |
# |    value_loss           | 0.00823     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 60          |
# |    time_elapsed         | 870         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.043842275 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.188      |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00339    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 0.00454     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 61          |
# |    time_elapsed         | 884         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.018259343 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.238      |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0235     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.00407     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 141        |
# |    iterations           | 62         |
# |    time_elapsed         | 899        |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.01297536 |
# |    clip_fraction        | 0.0827     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.236     |
# |    explained_variance   | 0.505      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0183    |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.0101    |
# |    value_loss           | 0.00492    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 63          |
# |    time_elapsed         | 913         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.013183291 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.123      |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0056     |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 141          |
# |    iterations           | 64           |
# |    time_elapsed         | 928          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0073123733 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.109       |
# |    explained_variance   | 0.418        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0253      |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.00482     |
# |    value_loss           | 0.00136      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# ...
# |    policy_gradient_loss | -0.00661     |
# |    value_loss           | 0.0011       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 225         |
# |    time_elapsed         | 2564        |
# |    total_timesteps      | 460800      |
# | train/                  |             |
# |    approx_kl            | 0.009827937 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0533     |
# |    explained_variance   | 0.452       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00476    |
# |    n_updates            | 2240        |
# |    policy_gradient_loss | -0.00385    |
# |    value_loss           | 0.000866    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 179          |
# |    iterations           | 226          |
# |    time_elapsed         | 2581         |
# |    total_timesteps      | 462848       |
# | train/                  |              |
# |    approx_kl            | 0.0053252163 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0538      |
# |    explained_variance   | 0.481        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00136     |
# |    n_updates            | 2250         |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 0.000904     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 227         |
# |    time_elapsed         | 2599        |
# |    total_timesteps      | 464896      |
# | train/                  |             |
# |    approx_kl            | 0.006325162 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.058      |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00251    |
# |    n_updates            | 2260        |
# |    policy_gradient_loss | 0.000463    |
# |    value_loss           | 0.000858    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 228         |
# |    time_elapsed         | 2616        |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.009355507 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0712     |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00931    |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 0.000906    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 178       |
# |    iterations           | 229       |
# |    time_elapsed         | 2634      |
# |    total_timesteps      | 468992    |
# | train/                  |           |
# |    approx_kl            | 0.044428  |
# |    clip_fraction        | 0.0496    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.077    |
# |    explained_variance   | 0.414     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -8.36e-05 |
# |    n_updates            | 2280      |
# |    policy_gradient_loss | -0.00352  |
# |    value_loss           | 0.00111   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 230         |
# |    time_elapsed         | 2652        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.011827572 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.115      |
# |    explained_variance   | 0.452       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00224    |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.0043     |
# |    value_loss           | 0.000941    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 177        |
# |    iterations           | 231        |
# |    time_elapsed         | 2670       |
# |    total_timesteps      | 473088     |
# | train/                  |            |
# |    approx_kl            | 0.01077994 |
# |    clip_fraction        | 0.0555     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.148     |
# |    explained_variance   | 0.407      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00831   |
# |    n_updates            | 2300       |
# |    policy_gradient_loss | -0.00849   |
# |    value_loss           | 0.00176    |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 176        |
# |    iterations           | 232        |
# |    time_elapsed         | 2688       |
# |    total_timesteps      | 475136     |
# | train/                  |            |
# |    approx_kl            | 0.01919221 |
# |    clip_fraction        | 0.0553     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.109     |
# |    explained_variance   | 0.448      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0128    |
# |    n_updates            | 2310       |
# |    policy_gradient_loss | -0.00792   |
# |    value_loss           | 0.00126    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 233         |
# |    time_elapsed         | 2705        |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.012949253 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.114      |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00544     |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.00755    |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 234         |
# |    time_elapsed         | 2723        |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.011049634 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.116      |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0154      |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00653    |
# |    value_loss           | 0.00107     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 235         |
# |    time_elapsed         | 2741        |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.010670988 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0958     |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00319    |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00576    |
# |    value_loss           | 0.00117     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 236         |
# |    time_elapsed         | 2758        |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.010069963 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0677     |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00087     |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.00466    |
# |    value_loss           | 0.000976    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 237         |
# |    time_elapsed         | 2776        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.006619281 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0539     |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00997     |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 0.000849    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 238         |
# |    time_elapsed         | 2794        |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.006325446 |
# |    clip_fraction        | 0.0363      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0961     |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.00177    |
# |    value_loss           | 0.00131     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 239         |
# |    time_elapsed         | 2812        |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.011799457 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0869     |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00469    |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00586    |
# |    value_loss           | 0.00126     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 240         |
# |    time_elapsed         | 2829        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.013322432 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0886     |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 173          |
# |    iterations           | 241          |
# |    time_elapsed         | 2847         |
# |    total_timesteps      | 493568       |
# | train/                  |              |
# |    approx_kl            | 0.0071402723 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0629      |
# |    explained_variance   | 0.428        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0028      |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 0.00125      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 242         |
# |    time_elapsed         | 2865        |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.008355208 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0416     |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00656    |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.00217    |
# |    value_loss           | 0.000808    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 243         |
# |    time_elapsed         | 2883        |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.004659243 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0409     |
# |    explained_variance   | 0.489       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00914     |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.0023     |
# |    value_loss           | 0.000877    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 172          |
# |    iterations           | 244          |
# |    time_elapsed         | 2901         |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0055713486 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0492      |
# |    explained_variance   | 0.477        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00597     |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 0.000872     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 245         |
# |    time_elapsed         | 2919        |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.005376556 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0637     |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000367    |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | 0.000811    |
# |    value_loss           | 0.00107     |
# -----------------------------------------

# %% [markdown]
# Interpret Results:
#
#
# | Parameter                | What It Means                            | Typical Range                     | How To Interpret                                                                                        |
# | ------------------------ | ---------------------------------------- | --------------------------------- | ------------------------------------------------------------------------------------------------------- |
# | **ep_len_mean**          | Average number of steps per episode      | 1 → max episode length (~100–200) | Lower is better. Decreasing over time = agent solving faster. High = wandering/failing.                 |
# | **ep_rew_mean**          | Average reward per episode               | 0 → 1 (MiniGrid)                  | Near 0 = failing. ~0.5 = partial success. Near 1 = strong performance. Should increase during training. |
# | **fps**                  | Frames per second (training speed)       | 100–1000+                         | Only measures speed. Not related to learning quality.                                                   |
# | **iterations**           | Number of PPO training cycles completed  | Increasing integer                | Just progress indicator.                                                                                |
# | **time_elapsed**         | Seconds since training started           | Increasing                        | Runtime only.                                                                                           |
# | **total_timesteps**      | Total environment steps taken            | 0 → chosen training limit         | Main measure of training progress.                                                                      |
# | **approx_kl**            | How much the policy changed in an update | 0.005 – 0.03 typical              | ~0.01–0.02 = healthy. Too high (>0.1) = unstable. Too low = slow learning.                              |
# | **clip_fraction**        | % of updates clipped by PPO              | 0.1 – 0.3 typical                 | ~0.2 normal. Near 0 = small updates. Near 1 = overly aggressive updates.                                |
# | **clip_range**           | PPO clipping threshold (hyperparameter)  | Usually 0.2                       | Fixed value. Controls update size constraint.                                                           |
# | **entropy_loss**         | Measures randomness of policy            | Negative number                   | More negative = more random. Should slowly decrease as agent learns.                                    |
# | **explained_variance**   | How well value function predicts returns | -∞ → 1                            | 1 = perfect. 0 = useless. <0 = bad. 0.3–0.8 during training = normal.                                   |
# | **learning_rate**        | Step size for neural network updates     | ~0.0003 default                   | Too high = unstable. Too low = slow learning.                                                           |
# | **loss**                 | Total combined PPO loss                  | Varies                            | Not very interpretable alone. Used for optimization.                                                    |
# | **policy_gradient_loss** | Policy improvement term                  | Small negative value              | Negative is normal. Large magnitude may indicate instability.                                           |
# | **value_loss**           | Error in value function prediction       | ≥ 0                               | Lower is better. Large values mean poor value predictions.                                              |
# | **n_updates**            | Number of gradient updates performed     | Increasing integer                | Indicates training progress.                                                                            |

# %% [markdown]
# -------------------------------------------------

# %% [markdown]
# Save PPO model

# %%
model.save("ppo_minigrid_model")

# %% [markdown]
# Evaluate on held-out test seeds

# %%
# 1) Sanity check: evaluate on a few TRAIN seeds (agent has seen these layouts)
train_eval_seeds = train_seeds[:5]  # first 5 train seeds
n_episodes_per_seed = 3
train_rewards = []
for seed in train_eval_seeds:
    eval_env = gym.make(env_id)
    eval_env = FlatObsWrapper(eval_env)
    for _ in range(n_episodes_per_seed):
        obs, _ = eval_env.reset(seed=int(seed))
        done, total_rew = False, 0.0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, _ = eval_env.step(action)
            done = terminated or truncated
            total_rew += reward
        train_rewards.append(total_rew)
    eval_env.close()
print(f"Mean reward on TRAIN seeds (sample {train_eval_seeds[0]}-{train_eval_seeds[-1]}): {np.mean(train_rewards):.4f} (+/- {np.std(train_rewards):.4f})")

# 2) Generalization: evaluate on held-out TEST seeds
test_seeds = list(range(100, 120))
rewards_per_seed = []
for seed in test_seeds:
    eval_env = gym.make(env_id)
    eval_env = FlatObsWrapper(eval_env)
    episode_rewards = []
    for _ in range(n_episodes_per_seed):
        obs, _ = eval_env.reset(seed=int(seed))
        done, total_rew = False, 0.0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, _ = eval_env.step(action)
            done = terminated or truncated
            total_rew += reward
        episode_rewards.append(total_rew)
    rewards_per_seed.append(np.mean(episode_rewards))
    eval_env.close()

print(f"Mean reward on TEST seeds ({test_seeds[0]}-{test_seeds[-1]}): {np.mean(rewards_per_seed):.4f} (+/- {np.std(rewards_per_seed):.4f})")
print(f"Min: {np.min(rewards_per_seed):.4f}, Max: {np.max(rewards_per_seed):.4f}")
# Out:
# Mean reward on TRAIN seeds (sample 0-4): 0.8290 (+/- 0.0305)
# Mean reward on TEST seeds (100-119): 0.8515 (+/- 0.0417)
# Min: 0.7750, Max: 0.9100

# %% [markdown]
# Evaluation after the first run, gave below results -
#
# Mean reward on test seeds (20-39): 0.0000 (+/- 0.0000)
# Min: 0.0000, Max: 0.0000
#
# Interpretation:
#
# On every evaluation episode (across all test seeds 20–39), the agent got no reward. So it never reached the goal on any of those levels.
# This shows strong overfitting, the policy learned layouts from seeds 0–19 and doesn’t transfer to the new layouts from 20–39. This is a failure mode of poor generalization.

# %% [markdown]
# Mitigation Stratergy
#
# 1. More training seeds (0–99 instead of 0–19)
# Before: The agent saw only 20 different level layouts.
# After: It sees 100 different layouts.
#
# 2. Longer training (500,000 steps instead of 200,000)
# Before: Training stopped earlier.
# After: Training runs 2.5× longer.The agent gets more experience and time to learn a good, general policy.
#
# 3. Better PPO settings
# Before: Mostly default hyperparameters.
# After: Set things like learning rate, number of epochs per update, batch size, etc. This makes it more stable and effective learning.
#
# 4. RandomSeedWrapper
# On every new episode, the training environment picks a random seed from 0–99 and resets with that seed.
# Each episode can be a different layout, so the agent really trains on many levels instead of repeating the same one.

# %% [markdown]
# Visualize Results

# %%
import time
from stable_baselines3 import PPO

model = PPO.load("ppo_minigrid_model")
test_seeds_visual = [100, 105, 110, 115]  # subset of test seeds (100-119)
step_delay = 0.15  # seconds between steps (increase to 0.3 if too fast)

for seed in test_seeds_visual:
    env = gym.make(env_id, render_mode="human")
    env = FlatObsWrapper(env)
    obs, _ = env.reset(seed=int(seed))
    total_rew = 0.0
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        print("action:", action)
        obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        total_rew += reward
        time.sleep(step_delay)  # pause so you can see: move, toggle door, go through, reach goal
    print(f"Seed {seed} — Episode reward: {total_rew:.4f}")
    env.close()

print("Done. Doors open when agent uses toggle (action 5) while facing them.")
# Out:
# action: 2
# action: 0
# action: 5
# action: 2
# action: 2
# action: 2
# Seed 100 — Episode reward: 0.8650
# action: 1
# action: 1
# action: 2
# action: 5
# action: 2
# action: 2
# action: 2
# Seed 105 — Episode reward: 0.8425
# action: 1
# action: 5
# action: 2
# action: 2
# Seed 110 — Episode reward: 0.9100
# action: 1
# action: 5
# action: 2
# action: 2
# action: 0
# action: 2
# Seed 115 — Episode reward: 0.8650
# Done. Doors open when agent uses toggle (action 5) while facing them.

# %% [markdown]
# With the current setup (many train seeds, random seed wrapper, 500K steps, entropy bonus), the agent did generalize: test performance slightly exceeds the train sample.
# Conclusion: The mitigations (diverse train seeds, randomization, enough training) helped the agent learn a robust policy that works on held-out test seeds, not just on the training set.
